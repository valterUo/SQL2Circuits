# %% [markdown]
# # Circuit learning method for SQL: training and test data generation

# %% [markdown]
# This notebook contains the data preparation and generation for the circuit learning process. Running the this notebook produces the training and test data which can be found from the `data` folder. This code is represented for reproducibility reasons and there is no need to rerun it every time. The queries are simplified versions of Join Order Benchmark queries.

# %% [markdown]
# ### PostgreSQL database preparation

# %% [markdown]
# Prerequisites:
#
# 1. You need to have PostgreSQL database installed and configured
# 2. You have downloaded the old but more comprehensive IMDB data set from year 2017. See the instructions and link to the files from [cinemagoer](https://cinemagoer.readthedocs.io/en/latest/usage/ptdf.html).
# 3. Create an empty database (imdb2017) for the user (postgres) with the following code:
#
# ```
# CREATE DATABASE imdb2017
# WITH OWNER postgres
# TEMPLATE = template0
# ENCODING UTF8
# LC_COLLATE = 'und-x-icu'
# LC_CTYPE = 'und-x-icu';
# ```
#
# IMDB is providing newer but less comprehensive [dataset](https://www.imdb.com/interfaces/). Cinemagoer describes how to upload that data into Postgres but because the join order benchmark queries are built on the older dataset, we also need to use the older one.

# %%
# Database credentials

port = "5432"
pg_db_name = "imdb2017"
pg_user = "postgres"
pg_pw = "0000"
imdb_file_path = "C:\\Users\\valte\\Documents\\frozendata"

pg_connection = "postgresql://" + pg_user + ":" + pg_pw + "@localhost:" + port + "/" + pg_db_name

# %% [markdown]
# The following code will use `imdbpy2sql` code to insert the internet movie database data into the created database. Note that the execution will probably take hours. Once the insert has been performed, comment the cell.

# %%
#!python cinemagoer\bin\imdbpy2sql.py -d {imdb_file_path} -u {pg_connection}

# %% [markdown]
# To speedup queries we create certain indeces.

# %%
import psycopg2

create_indices = """
create index company_id_movie_companies on movie_companies(company_id);
create index company_type_id_movie_companies on movie_companies(company_type_id);
create index info_type_id_movie_info on movie_info(info_type_id);
create index info_type_id_person_info on person_info(info_type_id);
create index keyword_id_movie_keyword on movie_keyword(keyword_id);
create index kind_id_aka_title on aka_title(kind_id);
create index kind_id_title on title(kind_id);
create index linked_movie_id_movie_link on movie_link(linked_movie_id);
create index link_type_id_movie_link on movie_link(link_type_id);
create index movie_id_aka_title on aka_title(movie_id);
create index movie_id_cast_info on cast_info(movie_id);
create index movie_id_complete_cast on complete_cast(movie_id);
create index movie_id_movie_companies on movie_companies(movie_id);
create index movie_id_movie_keyword on movie_keyword(movie_id);
create index movie_id_movie_link on movie_link(movie_id);
create index movie_id_movie_info on movie_info(movie_id);
create index person_id_aka_name on aka_name(person_id);
create index person_id_cast_info on cast_info(person_id);
create index person_id_person_info on person_info(person_id);
create index person_role_id_cast_info on cast_info(person_role_id);
create index role_id_cast_info on cast_info(role_id);
"""

test_query = "EXPLAIN ANALYZE SELECT * FROM title LIMIT 2;"

try:
    connection = psycopg2.connect(user=pg_user, password=pg_pw, host="localhost", port=port, database=pg_db_name)
    cursor = connection.cursor()
    cursor.execute(create_indices)
    res = cursor.fetchall()
    print(res)

except (Exception, psycopg2.Error) as error:
    print("Error while fetching data from PostgreSQL", error)

finally:
    # closing database connection.
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Error while fetching data from PostgreSQL relation "company_id_movie_companies" already exists
#
# PostgreSQL connection is closed

# %% [markdown]
# ## Create training and test data

# %% [markdown]
# Training and test data are stored to `data` folder in json files.

# %%
# Read queries from the join order benchmark
import glob
import os
import re
import json
from pathlib import Path

this_folder = os.path.abspath(os.getcwd())
training_queries, validation_queries, test_queries = [], [], []
query_path_JOB = glob.glob(this_folder + "\\join-order-benchmark-queries\\[0-9]*.sql")
query_path_training = glob.glob(this_folder + "\\queries\\training_queries\\[0-9]*.sql")
query_path_validation = glob.glob(this_folder + "\\queries\\validation_queries\\[0-9]*.sql")
query_path_test = glob.glob(this_folder + "\\queries\\test_queries\\[0-9]*.sql")

for i, query in enumerate(query_path_training):
    base_name = Path(query).stem
    f = open(query, "r")
    training_queries.append({ 'name': base_name, 'query': f.read() })
    
for i, query in enumerate(query_path_validation):
    base_name = Path(query).stem
    f = open(query, "r")
    validation_queries.append({ 'name': base_name, 'query': f.read() })
        
for i, query in enumerate(query_path_test):
    base_name = Path(query).stem
    f = open(query, "r")
    test_queries.append({ 'name': base_name, 'query': f.read() })
        
print("Number of training queries is ", len(training_queries))
print("Number of validation queries is ", len(validation_queries))
print("Number of test queries is ", len(test_queries))
# Out:
# Number of training queries is  1106
# Number of validation queries is  277
# Number of test queries is  276

# %% [markdown]
# ### Generating training and test data

# %%
def genereta_data(queries, ty = "training"):
    connection = psycopg2.connect(user=pg_user, password=pg_pw, host="localhost", port=port, database=pg_db_name)
    cursor = connection.cursor()
    cursor.execute("SET statement_timeout = 20000; COMMIT;")
    shots_per_query = 10
    data = []
    file_name = "data\\training_data.json"
    root_name = "training_data"

    for query in queries:
        try:
            total_running_time = 0.0
            for i in range(shots_per_query):
                cursor = connection.cursor()
                cursor.execute("EXPLAIN ANALYZE " + query['query'])
                res = cursor.fetchall()
                ex_time = float(re.findall("\d+\.\d+", res[-1][0])[0])
                plan_time = float(re.findall("\d+\.\d+", res[-2][0])[0])
                total_running_time += ex_time + plan_time
            #print(total_running_time / shots_per_query)
            data.append( {'name': query['name'], 'time': round(total_running_time / shots_per_query, 4) })

        except (Exception, psycopg2.Error) as error:
            print("Error while fetching data from PostgreSQL", error)
            print(query)

    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
    
    if ty == "test":
        file_name = "data\\test_data.json"
        root_name = "test_data"
    elif ty == "validation":
        file_name = "data\\validation_data.json"
        root_name = "validation_data"
        
    with open(file_name, 'w') as outfile:
        json.dump({ root_name: data }, outfile)

# %%
genereta_data(training_queries, "training")
genereta_data(validation_queries, "validation")
genereta_data(test_queries, "test")
# Out:
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1001', 'query': "SELECT MIN(mi.info) AS release_date FROM aka_name AS an, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND an.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1003', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1021', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_info AS mi, movie_companies AS mc, movie_keyword AS mk WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mk.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1022', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, movie_info AS mi WHERE an.name LIKE '%a%' AND an.person_id = ci.person_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1025', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, person_info AS pi WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND pi.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1030', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1031', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note IS NULL AND mc.movie_id = mi.movie_id AND mk.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1033', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND ml.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1064', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ml.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1072', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND ci.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1084', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1088', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.linked_movie_id = mc.movie_id AND ml.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '109', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND ml.linked_movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '11', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, movie_companies AS mc WHERE an.name LIKE '%a%' AND an.person_id = ci.person_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1103', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NULL AND ml.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1105', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1106', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, title AS t, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND t.id = ci.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1114', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_name AS an, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND an.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1154', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_info AS mi, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND mk.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '116', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, person_info AS pi WHERE an.name LIKE '%a%' AND an.person_id = ci.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1163', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, movie_link AS ml, cast_info AS ci WHERE an.name LIKE '%a%' AND an.person_id = ci.person_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1169', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1186', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NULL AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1199', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year > 2004 AND ml.linked_movie_id = t.id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1204', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, name AS n WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND n.id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1211', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year < 2011 AND t.id = mi.movie_id AND t.id = ci.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1216', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, name AS n WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND n.id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '122', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND ml.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1231', 'query': "SELECT MIN(n.name) AS actor_name FROM movie_link AS ml, cast_info AS ci, name AS n WHERE n.gender='m' AND n.id = ci.person_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1232', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, movie_info AS mi WHERE n.gender='f' AND n.id = ci.person_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1252', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_name AS an, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND an.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1261', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1262', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1274', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1279', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='m' AND n.id = ci.person_id AND n.id = pi.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1282', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, person_info AS pi WHERE an.name LIKE '%a%' AND pi.person_id = an.person_id AND an.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1288', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='m' AND n.id = pi.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1292', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_info AS mi, cast_info AS ci, movie_keyword AS mk WHERE mi.info IN ('Sweden', 'USA', 'German') AND mk.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1321', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(co-production)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1330', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year < 2011 AND ml.movie_id = t.id AND t.id = ci.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1360', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mi.movie_id AND mi.movie_id = at.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1381', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='f' AND n.id = pi.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1384', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1391', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_info AS mi, cast_info AS ci, movie_keyword AS mk WHERE mi.info IN ('Sweden', 'USA', 'German') AND mk.movie_id = mi.movie_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1396', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND ml.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1405', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND ml.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1412', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, person_info AS pi WHERE an.name LIKE '%a%' AND an.person_id = ci.person_id AND pi.person_id = an.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1423', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(co-production)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1435', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '145', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND ml.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1460', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND ml.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1475', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(presents)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1493', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_info AS mi, movie_link AS ml, movie_keyword AS mk WHERE mi.info IN ('Sweden', 'USA', 'German') AND mk.movie_id = mi.movie_id AND ml.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '155', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1555', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.linked_movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1570', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(presents)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1577', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year < 2011 AND ml.movie_id = t.id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1582', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.movie_id = mc.movie_id AND ml.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1600', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, movie_keyword AS mk, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1648', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1657', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND ml.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '169', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '2', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, movie_keyword AS mk, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ml.movie_id = mi.movie_id AND ml.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '205', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = at.movie_id AND mk.movie_id = at.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '224', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND ml.linked_movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '227', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mi.movie_id AND ml.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '244', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ci.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '248', 'query': 'SELECT MIN(mc.note) AS production_note FROM company_name AS cn, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND cn.id = mc.company_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '254', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, movie_info AS mi WHERE n.name LIKE 'B%' AND n.id = ci.person_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '26', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '262', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '265', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND ci.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '269', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '292', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='m' AND n.id = ci.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '295', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = mi.movie_id AND mk.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '313', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '32', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = at.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '350', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '361', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note LIKE '%(presents)%' AND mc.movie_id = mi.movie_id AND mk.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '373', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year > 2004 AND ml.movie_id = t.id AND t.id = ci.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '377', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, person_info AS pi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '379', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = at.movie_id AND mi.movie_id = at.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '407', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '425', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ml.linked_movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '439', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '458', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ml.movie_id = mi.movie_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '46', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year > 2004 AND t.id = ci.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '463', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, info_type AS it, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND it.id = mi.info_type_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '472', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND mk.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '490', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, person_info AS pi, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '5', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NULL AND mc.movie_id = mi.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '50', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_info AS mi, movie_companies AS mc, movie_keyword AS mk WHERE mc.note LIKE '%(presents)%' AND mc.movie_id = mk.movie_id AND mk.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '511', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '518', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, title AS t, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND t.id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '526', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year > 2004 AND t.id = mi.movie_id AND t.id = ci.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '53', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '587', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND ml.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '592', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '593', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note IS NULL AND mc.movie_id = mi.movie_id AND mc.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '607', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year > 2004 AND ml.movie_id = t.id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '613', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, movie_keyword AS mk WHERE n.gender='m' AND n.id = ci.person_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '622', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(presents)%' AND ci.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '640', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='f' AND n.id = ci.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '646', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='f' AND n.id = pi.person_id AND n.id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '67', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note LIKE '%(presents)%' AND mc.movie_id = mi.movie_id AND mc.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '674', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, person_info AS pi WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND pi.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '686', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='f' AND n.id = ci.person_id AND n.id = pi.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '688', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year > 2004 AND t.id = ci.movie_id AND t.id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '7', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NULL AND mc.movie_id = mk.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '700', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mi.movie_id AND ml.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '707', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND ci.movie_id = mc.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '709', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '725', 'query': "SELECT MIN(an.name) AS actress_pseudonym FROM aka_name AS an, cast_info AS ci, person_info AS pi WHERE an.name LIKE '%a%' AND pi.person_id = an.person_id AND pi.person_id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '736', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND ml.linked_movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '739', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = mi.movie_id AND ml.linked_movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '745', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND ml.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '748', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = mi.movie_id AND mi.movie_id = at.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '76', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = at.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '761', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, info_type AS it, movie_info AS mi WHERE it.info ='rating' AND it.id = mi.info_type_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '769', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NOT NULL AND mc.movie_id = mi.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '778', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_name AS an, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND an.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '791', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '808', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, info_type AS it, movie_info AS mi WHERE it.info = 'top 250 rank' AND it.id = mi.info_type_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '830', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '878', 'query': "SELECT MIN(n.name) AS actor_name FROM cast_info AS ci, name AS n, person_info AS pi WHERE n.gender='m' AND n.id = pi.person_id AND n.id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '884', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, info_type AS it, movie_info AS mi WHERE it.info = 'bottom 10 rank' AND it.id = mi.info_type_id AND ci.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '89', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, name AS n, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND n.id = ci.person_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '908', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ml.movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '92', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NULL AND ml.linked_movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '935', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_info AS mi, movie_link AS ml, movie_keyword AS mk WHERE mi.info IN ('Sweden', 'USA', 'German') AND mk.movie_id = mi.movie_id AND ml.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '947', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year < 2011 AND t.id = ci.movie_id AND t.id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '949', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_title AS at, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND mc.movie_id = at.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '985', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '995', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, movie_info AS mi WHERE t.production_year > 2004 AND t.id = mi.movie_id AND ci.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '997', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, name AS n WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND n.id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '998', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND ml.movie_id = mc.movie_id;"}
# PostgreSQL connection is closed
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1176', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_info AS mi, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NULL AND mc.movie_id = mk.movie_id AND mk.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1182', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note IS NULL AND ci.movie_id = mc.movie_id AND mc.movie_id = mi.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1194', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND ml.linked_movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1236', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_info AS mi, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND mc.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1254', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ml.linked_movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1272', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, movie_keyword AS mk, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ml.movie_id = mi.movie_id AND mk.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1278', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, person_info AS pi WHERE t.production_year < 2011 AND t.id = ci.movie_id AND pi.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1422', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NULL AND ml.movie_id = mc.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1494', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ml.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '1506', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '174', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = at.movie_id AND mi.movie_id = at.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '18', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND mc.movie_id = mk.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '186', 'query': 'SELECT MIN(t.title) AS movie_title FROM movie_link AS ml, cast_info AS ci, title AS t WHERE t.production_year < 2011 AND ml.linked_movie_id = t.id AND t.id = ci.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '264', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NULL AND ml.movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '282', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mk.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '288', 'query': 'SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND ci.movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '360', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND ci.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '378', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ci.movie_id = mc.movie_id AND ml.movie_id = mc.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '42', 'query': "SELECT MIN(mi.info) AS release_date FROM movie_link AS ml, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND ci.movie_id = ml.linked_movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '486', 'query': "SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mi.movie_id AND mc.movie_id = at.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '492', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mk.movie_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '504', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND ml.linked_movie_id = mc.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '534', 'query': 'SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NULL AND ml.linked_movie_id = mc.movie_id AND ci.movie_id = ml.linked_movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '540', 'query': "SELECT MIN(mi.info) AS release_date FROM role_type AS rt, cast_info AS ci, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND ci.role_id = rt.id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '558', 'query': 'SELECT MIN(mc.note) AS production_note FROM aka_title AS at, movie_companies AS mc, movie_keyword AS mk WHERE mc.note IS NOT NULL AND mc.movie_id = mk.movie_id AND mk.movie_id = at.movie_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '582', 'query': 'SELECT MIN(mc.note) AS production_note FROM company_type AS ct, cast_info AS ci, movie_companies AS mc WHERE mc.note IS NOT NULL AND ci.movie_id = mc.movie_id AND ct.id = mc.company_type_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '588', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, aka_title AS at, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND mi.movie_id = at.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '6', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_info AS mi WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND ml.linked_movie_id = mc.movie_id AND ml.movie_id = mi.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '60', 'query': "SELECT MIN(mc.note) AS production_note FROM cast_info AS ci, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND ci.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '738', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_companies AS mc, movie_keyword AS mk, movie_info AS mi WHERE mc.note LIKE '%(France)%' AND mc.movie_id = mi.movie_id AND mc.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '756', 'query': "SELECT MIN(mc.note) AS production_note FROM movie_link AS ml, movie_companies AS mc, movie_keyword AS mk WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND mc.movie_id = mk.movie_id AND ml.movie_id = mk.movie_id;"}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '78', 'query': 'SELECT MIN(t.title) AS movie_title FROM cast_info AS ci, title AS t, person_info AS pi WHERE t.production_year > 2004 AND t.id = ci.movie_id AND pi.person_id = ci.person_id;'}
# Error while fetching data from PostgreSQL canceling statement due to statement timeout
#
# {'name': '780', 'query': "SELECT MIN(mi.info) AS release_date FROM cast_info AS ci, info_type AS it, movie_info AS mi WHERE mi.info IN ('Sweden', 'USA', 'German') AND ci.movie_id = mi.movie_id AND it.id = mi.info_type_id;"}

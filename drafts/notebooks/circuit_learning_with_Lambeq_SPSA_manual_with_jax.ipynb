# %% [markdown]
# # Circuit learning module: Lambeq manually with SPSA and JAX

# %% [markdown]
# This module performs the optimization of the parametrized circuit manually compared to Lambeq's automatic QuantumTrainer class. I created this because I wanted to have more control over the optimization process and debug it better. The code is based on the workflow presented in https://github.com/CQCL/Quanthoven.

# %%
import warnings
import json
import os
import sys
import glob
from math import ceil
from pathlib import Path
from jax import numpy as np
from sympy import default_sort_key
import numpy
import pickle
import matplotlib.pyplot as plt

import jax
from jax import jit
from noisyopt import minimizeSPSA, minimizeCompass

from discopy.quantum import Circuit
from discopy.tensor import Tensor
from discopy.utils import loads
#from pytket.extensions.qiskit import AerBackend
#from pytket.extensions.qulacs import QulacsBackend
#from pytket.extensions.cirq import CirqStateSampleBackend
backend = None

from utils import *
#from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

warnings.filterwarnings('ignore')
this_folder = os.path.abspath(os.getcwd())
os.environ['TOKENIZERS_PARALLELISM'] = 'true'
#os.environ["JAX_PLATFORMS"] = "cpu"

SEED = 0

# This avoids TracerArrayConversionError from jax
Tensor.np = np

rng = numpy.random.default_rng(SEED)
numpy.random.seed(SEED)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       6 from math import ceil
#       7 from pathlib import Path
# ----> 8 from jax import numpy as np
#       9 from sympy import default_sort_key
#      10 import numpy
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\__init__.py:21, in <module>
#      18 del _os
#      20 # flake8: noqa: F401
# ---> 21 from .config import config
#      22 from .api import (
#      23   ad,  # TODO(phawkins): update users to avoid this.
#      24   argnums_partial,  # TODO(phawkins): update Haiku to not use this.
#    (...)
#      87   xla_computation,
#      88 )
#      89 from .experimental.maps import soft_pmap
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\config.py:19, in <module>
#      17 import threading
#      18 from typing import Optional
# ---> 19 from jax import lib
#      21 def bool_env(varname: str, default: bool) -> bool:
#      22   """Read an environment variable and interpret it as a boolean.
#      23
#      24   True values are (case insensitive): 'y', 'yes', 't', 'true', 'on', and '1';
#    (...)
#      30   Raises: ValueError if the environment variable is anything else.
#      31   """
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\jax\lib\__init__.py:23, in <module>
#       1 # Copyright 2018 Google LLC
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      15 # This module is largely a wrapper around `jaxlib` that performs version
#      16 # checking on import.
#      18 __all__ = [
#      19   'cuda_prng', 'cusolver', 'rocsolver', 'jaxlib', 'lapack',
#      20   'pocketfft', 'pytree', 'tpu_client', 'version', 'xla_client'
#      21 ]
# ---> 23 import jaxlib
#      25 # Must be kept in sync with the jaxlib version in build/test-requirements.txt
#      26 _minimum_jaxlib_version = (0, 1, 60)
#
# ModuleNotFoundError: No module named 'jaxlib'

# %% [markdown]
# ## Read circuit data

# %% [markdown]
# We read the circuits from the pickled files. Select if we perform binary classification or multi-class classification. Give number of qubits to create classes:
# - 1 qubits -> 2^1 = 2 classes i.e. binary classification
# - 2 qubits -> 2^2 = 4 classes
# - ...
# - 5 qubits -> 2^5 = 32 classes, etc.

# %%
# Select workload
workload = "execution_time"
#workload = "cardinality"

# Select workload size
#workload_size = "small"
#workload_size = "medium"
#workload_size = "large"
workload_size = "main"

classification = 3
layers = 1
single_qubit_params = 3
n_wire_count = 1

loss = multi_class_loss
acc = multi_class_acc

if classification == 1:
    loss = bin_class_loss
    acc = bin_class_acc

# Access the selected circuits
path_name = this_folder + "//simplified-JOB-diagrams//" + workload + "//" + workload_size + "//circuits//" + str(classification) + "//" + str(layers) + "_layer//" + str(single_qubit_params) + "_single_qubit_params//" + str(n_wire_count) + "_n_wire_count//"

training_circuits_paths = glob.glob(path_name + "training//[0-9]*.p")
validation_circuits_paths = glob.glob(path_name + "validation//[0-9]*.p")
test_circuits_paths = glob.glob(path_name + "test//[0-9]*.p")

# %%
training_circuits = read_diagrams(training_circuits_paths)
validation_circuits = read_diagrams(validation_circuits_paths)
test_circuits = read_diagrams(test_circuits_paths)

# %% [markdown]
# ## Read training and test data

# %%
training_data, test_data, validation_data = None, None, None
data_path = this_folder + "//data//" + workload + "//" + workload_size + "//"

with open(data_path + "training_data.json", "r") as inputfile:
    training_data = json.load(inputfile)['training_data']
with open(data_path + "test_data.json", "r") as inputfile:
    test_data = json.load(inputfile)['test_data']
with open(data_path + "validation_data.json", "r") as inputfile:
    validation_data = json.load(inputfile)['validation_data']

training_data_labels, classes = create_labeled_training_classes(training_data, classification, workload)
test_data_labels = create_labeled_test_validation_classes(test_data, classes, workload)
validation_data_labels = create_labeled_test_validation_classes(validation_data, classes, workload)

# %% [markdown]
# ## Model

# %%
def make_pred_fn(circuits):
    # In the case we want to use other backends. 
    # Currently does not work properly.
    if backend:
        compiled_circuits1 = backend.get_compiled_circuits([c.to_tk() for c in circuits])
        circuits = [Circuit.from_tk(c) for c in compiled_circuits1]
        
    circuit_fns = [c.lambdify(*parameters) for c in circuits]
    
    def predict(params):
        outputs = Circuit.eval(*(c(*params) for c in circuit_fns), backend = backend)
        res = []
        
        for output in outputs:
            predictions = np.abs(output.array) + 1e-9
            ratio = predictions / predictions.sum()
            res.append(ratio)
            
        return np.array(res)
    return predict

# %% [markdown]
# ## Loss function and evaluation

# %%
def make_cost_fn(pred_fn, labels):
    def cost_fn(params, **kwargs):
        predictions = pred_fn(params)
        #print(predictions, labels)
        
        cost = loss(predictions, labels) #-np.sum(labels * np.log(predictions)) / len(labels)  # binary cross-entropy loss
        costs.append(cost)

        accuracy = acc(predictions, labels) #np.sum(np.round(predictions) == labels) / len(labels) / 2  # half due to double-counting
        accuracies.append(accuracy)

        return cost

    costs, accuracies = [], []
    return cost_fn, costs, accuracies

# %% [markdown]
# ## Minimization with noisyopt

# %%
def initialize_parameters(old_params, old_values, new_params):
    new_values = list(numpy.array(rng.random(len(new_params))))
    old_param_dict = {}
    for p, v in zip(old_params, old_values):
        old_param_dict[p] = v
        
    parameters = sorted(set(old_params + new_params), key=default_sort_key)
    values = []
    for p in parameters:
        if p in old_param_dict:
            values.append(old_param_dict[p])
        else:
            values.append(new_values.pop())
            
    return parameters, np.array(values)

# %%
EPOCHS = 10000
initial_number_of_circuits = 20
syms = {}
limit = False
all_training_keys = list(training_circuits.keys())
initial_circuit_keys = all_training_keys[:initial_number_of_circuits + 1]
current_training_circuits = {}
result_file = workload + "_" + workload_size + "_noisyopt_1_" + str(classification) + "_" + str(layers) + "_" + str(single_qubit_params)

for k in initial_circuit_keys:
    current_training_circuits[k] = training_circuits[k]
    
syms = get_symbols(current_training_circuits)
parameters = sorted(syms, key=default_sort_key)
if initial_number_of_circuits > 10 and os.path.exists("points//" + result_file + ".npz"):
    with open("points//" + result_file + ".npz", "rb") as f:
        print("Loading parameters from file " + result_file)
        npzfile = np.load(f)
        init_params_spsa = npzfile['arr_0']
else:
    print("Initializing new parameters")
    init_params_spsa = np.array(rng.random(len(parameters)))
result = None
run = 0
# Out:
# WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Initializing new parameters

# %%
result = None

for i, key in enumerate(all_training_keys[initial_number_of_circuits:]):
    print("Progress: ", round((i + initial_number_of_circuits)/len(all_training_keys), 3))
    
    if len(syms) == len(get_symbols(current_training_circuits)) and i > 0:
        if i != len(all_training_keys[1:]):
            current_training_circuits[key] = training_circuits[key]
            new_parameters = sorted(get_symbols({key: training_circuits[key]}), key=default_sort_key)
            if result:
                parameters, init_params_spsa = initialize_parameters(parameters, result.x, new_parameters)
                #continue
            else:
                syms = get_symbols(current_training_circuits)
                parameters = sorted(syms, key=default_sort_key)
                init_params_spsa = np.array(rng.random(len(parameters)))
    else:
        run += 1
    
    # Select those circuits from test and validation circuits which share the parameters with the current training circuits
    current_validation_circuits = select_circuits(current_training_circuits, validation_circuits)
    current_test_circuits = select_circuits(current_training_circuits, test_circuits)
    
    if len(current_validation_circuits) == 0 or len(current_test_circuits) == 0:
        continue
    
    # Create lists with circuits and their corresponding label
    training_circuits_l, training_data_labels_l = construct_data_and_labels(current_training_circuits, training_data_labels)
    validation_circuits_l, validation_data_labels_l = construct_data_and_labels(current_validation_circuits, validation_data_labels)
    test_circuits_l, test_data_labels_l = construct_data_and_labels(current_test_circuits, test_data_labels)
    
    # Limit the number of validation and test circuits to 20% of number of the training circuits
    if limit:
        val_test_circ_size = ceil(len(current_training_circuits))
        if len(current_validation_circuits) > val_test_circ_size:
            validation_circuits_l = validation_circuits_l[:val_test_circ_size]
            validation_data_labels_l = validation_data_labels_l[:val_test_circ_size]
        if len(current_test_circuits) > val_test_circ_size:
            test_circuits_l = test_circuits_l[:val_test_circ_size]
            test_data_labels_l = test_data_labels_l[:val_test_circ_size]
    
    stats = f"Number of training circuits: {len(training_circuits_l)}   "\
        + f"Number of validation circuits: {len(validation_circuits_l)}   "\
        + f"Number of test circuits: {len(test_circuits_l)}   "\
        + f"Number of parameters in model: {len(set([sym for circuit in training_circuits_l for sym in circuit.free_symbols]))}"
    
    with open("results//" + result_file + ".txt", "a") as f:
        f.write(stats + "\n")
    
    print(stats)
    
    optimization_interval = 20
    
    if result == None or run % optimization_interval == 0:
    
        train_pred_fn = jit(make_pred_fn(training_circuits_l))
        dev_pred_fn = jit(make_pred_fn(validation_circuits_l))
        test_pred_fn = make_pred_fn(test_circuits_l)

        train_cost_fn, train_costs, train_accs = make_cost_fn(train_pred_fn, training_data_labels_l)
        dev_cost_fn, dev_costs, dev_accs = make_cost_fn(dev_pred_fn, validation_data_labels_l)

        def callback_fn(xk):
            #print(xk)
            valid_loss = dev_cost_fn(xk)
            train_loss = numpy.around(min(float(train_costs[-1]), float(train_costs[-2])), 4)
            train_acc = numpy.around(min(float(train_accs[-1]), float(train_accs[-2])), 4)
            valid_acc = numpy.around(float(dev_accs[-1]), 4)
            iters = int(len(train_accs)/2)
            if iters % 200 == 0:
                info = f"Epoch: {iters}   "\
                + f"train/loss: {train_loss}   "\
                + f"valid/loss: {numpy.around(float(valid_loss), 4)}   "\
                + f"train/acc: {train_acc}   "\
                + f"valid/acc: {valid_acc}"

                with open("results//" + result_file + ".txt", "a") as f:
                    f.write(info + "\n")

                print(info, file=sys.stderr)
            return valid_loss

        #a_value = 0.0053
        #c_value = 0.0185

        # Good
        #a_value = 0.053
        #c_value = 0.00185
        
        a_value = 0.01 #*(1/run)
        c_value = 0.01 #*(1/run)
        
        a_values = [0.1, 0.01, 0.001, 0.0001]
        c_values = [1, 0.1, 0.01, 0.001, 0.0001]
        
        print(a_value, c_value)
        train_cost_fn, train_costs, train_accs = make_cost_fn(train_pred_fn, training_data_labels_l)
        dev_cost_fn, dev_costs, dev_accs = make_cost_fn(dev_pred_fn, validation_data_labels_l)
        
        #for a_value in a_values:
        #    for c_value in c_values:
        #print(a_value, c_value)
        result = minimizeSPSA(train_cost_fn, x0=init_params_spsa, a = a_value, c = c_value, niter=EPOCHS, callback=callback_fn)
        #result = minimizeCompass(train_cost_fn, x0=init_params_spsa, redfactor=2.0, deltainit=1.0, deltatol=0.001, feps=1e-15, errorcontrol=True, funcNinit=30, funcmultfactor=2.0, paired=True, alpha=0.05, callback=callback_fn)

        figure_path = this_folder + "//results//" + result_file + ".png"
        visualize_result_noisyopt(result, make_cost_fn, test_pred_fn, test_data_labels_l, train_costs, train_accs, dev_costs, dev_accs, figure_path, result_file)
    
    run += 1
    #EPOCHS += 100
    syms = get_symbols(current_training_circuits)
    
    # Extend for the next optimization round
    current_training_circuits[key] = training_circuits[key]
    new_parameters = sorted(get_symbols({key: training_circuits[key]}), key=default_sort_key)
    parameters, init_params_spsa = initialize_parameters(parameters, result.x, new_parameters)
# Out:
# Progress:  0.045
# Number of training circuits: 20   Number of validation circuits: 82   Number of test circuits: 78   Number of parameters in model: 202
# 0.01 0.01
# Epoch: 200   train/loss: 4.2933   valid/loss: 22.7805   train/acc: 0.2   valid/acc: 0.1098
# Epoch: 400   train/loss: 4.0362   valid/loss: 24.159   train/acc: 0.15   valid/acc: 0.1098
# Epoch: 600   train/loss: 3.8465   valid/loss: 24.4325   train/acc: 0.15   valid/acc: 0.1341
# Epoch: 800   train/loss: 3.8827   valid/loss: 24.3819   train/acc: 0.35   valid/acc: 0.0854
# Epoch: 1000   train/loss: 3.7854   valid/loss: 24.1904   train/acc: 0.25   valid/acc: 0.1463
# Epoch: 1200   train/loss: 3.7466   valid/loss: 24.2107   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 1400   train/loss: 3.736   valid/loss: 24.4524   train/acc: 0.35   valid/acc: 0.1098
# Epoch: 1600   train/loss: 3.6369   valid/loss: 24.7901   train/acc: 0.4   valid/acc: 0.1463
# Epoch: 1800   train/loss: 3.5735   valid/loss: 24.6498   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 2000   train/loss: 3.6247   valid/loss: 25.117   train/acc: 0.3   valid/acc: 0.1098
# Epoch: 2200   train/loss: 3.6075   valid/loss: 25.0278   train/acc: 0.3   valid/acc: 0.0854
# Epoch: 2400   train/loss: 3.5448   valid/loss: 25.1751   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 2600   train/loss: 3.4921   valid/loss: 25.2071   train/acc: 0.25   valid/acc: 0.0854
# Epoch: 2800   train/loss: 3.4754   valid/loss: 25.4669   train/acc: 0.3   valid/acc: 0.0488
# Epoch: 3000   train/loss: 3.442   valid/loss: 25.5642   train/acc: 0.45   valid/acc: 0.0976
# Epoch: 3200   train/loss: 3.4195   valid/loss: 25.8122   train/acc: 0.25   valid/acc: 0.061
# Epoch: 3400   train/loss: 3.3527   valid/loss: 26.1178   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 3600   train/loss: 3.3393   valid/loss: 26.4316   train/acc: 0.25   valid/acc: 0.1098
# Epoch: 3800   train/loss: 3.3141   valid/loss: 27.1191   train/acc: 0.35   valid/acc: 0.0976
# Epoch: 4000   train/loss: 3.3459   valid/loss: 26.8761   train/acc: 0.3   valid/acc: 0.0854
# Epoch: 4200   train/loss: 3.3013   valid/loss: 26.9985   train/acc: 0.35   valid/acc: 0.0366
# Epoch: 4400   train/loss: 3.3216   valid/loss: 27.0525   train/acc: 0.2   valid/acc: 0.0854
# Epoch: 4600   train/loss: 3.2482   valid/loss: 27.263   train/acc: 0.25   valid/acc: 0.061
# Epoch: 4800   train/loss: 3.2305   valid/loss: 27.2672   train/acc: 0.35   valid/acc: 0.1098
# Epoch: 5000   train/loss: 3.1759   valid/loss: 27.1583   train/acc: 0.45   valid/acc: 0.0976
# Epoch: 5200   train/loss: 3.1451   valid/loss: 27.8553   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 5400   train/loss: 3.1387   valid/loss: 27.4683   train/acc: 0.2   valid/acc: 0.0976
# Epoch: 5600   train/loss: 3.0626   valid/loss: 28.1221   train/acc: 0.4   valid/acc: 0.0732
# Epoch: 5800   train/loss: 3.0546   valid/loss: 27.8711   train/acc: 0.35   valid/acc: 0.0854
# Epoch: 6000   train/loss: 3.1006   valid/loss: 27.7773   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 6200   train/loss: 3.053   valid/loss: 27.9963   train/acc: 0.3   valid/acc: 0.0366
# Epoch: 6400   train/loss: 3.0141   valid/loss: 27.4454   train/acc: 0.4   valid/acc: 0.1098
# Epoch: 6600   train/loss: 3.0845   valid/loss: 27.9217   train/acc: 0.35   valid/acc: 0.0976
# Epoch: 6800   train/loss: 3.0062   valid/loss: 27.7097   train/acc: 0.3   valid/acc: 0.0976
# Epoch: 7000   train/loss: 3.0603   valid/loss: 27.5356   train/acc: 0.45   valid/acc: 0.1098
# Epoch: 7200   train/loss: 2.9651   valid/loss: 27.6899   train/acc: 0.3   valid/acc: 0.0854
# Epoch: 7400   train/loss: 3.0135   valid/loss: 27.4114   train/acc: 0.4   valid/acc: 0.1098
# Epoch: 7600   train/loss: 2.9709   valid/loss: 27.4118   train/acc: 0.3   valid/acc: 0.1098
# Epoch: 7800   train/loss: 2.9249   valid/loss: 28.1084   train/acc: 0.2   valid/acc: 0.0976
# Epoch: 8000   train/loss: 2.9541   valid/loss: 27.7297   train/acc: 0.2   valid/acc: 0.0732
# Epoch: 8200   train/loss: 2.9508   valid/loss: 27.6338   train/acc: 0.4   valid/acc: 0.1098
# Epoch: 8400   train/loss: 2.925   valid/loss: 27.7903   train/acc: 0.1   valid/acc: 0.0854
# Epoch: 8600   train/loss: 2.913   valid/loss: 27.8272   train/acc: 0.4   valid/acc: 0.1341
# Epoch: 8800   train/loss: 2.9046   valid/loss: 27.9379   train/acc: 0.4   valid/acc: 0.0854
# Epoch: 9000   train/loss: 2.9001   valid/loss: 27.8736   train/acc: 0.2   valid/acc: 0.0976
# Epoch: 9200   train/loss: 2.9033   valid/loss: 28.1754   train/acc: 0.4   valid/acc: 0.0854
# Epoch: 9400   train/loss: 2.9088   valid/loss: 28.5115   train/acc: 0.4   valid/acc: 0.0488
# Epoch: 9600   train/loss: 2.9346   valid/loss: 28.5971   train/acc: 0.3   valid/acc: 0.0854
# Epoch: 9800   train/loss: 2.8782   valid/loss: 28.5272   train/acc: 0.4   valid/acc: 0.061
# Epoch: 10000   train/loss: 2.8888   valid/loss: 28.7885   train/acc: 0.3   valid/acc: 0.0854
# Test accuracy: 0.15384615384615385
# Progress:  0.047
# Number of training circuits: 21   Number of validation circuits: 82   Number of test circuits: 81   Number of parameters in model: 205
# Progress:  0.049
# Number of training circuits: 22   Number of validation circuits: 82   Number of test circuits: 81   Number of parameters in model: 205
# Progress:  0.051
# Number of training circuits: 23   Number of validation circuits: 82   Number of test circuits: 81   Number of parameters in model: 205
# Progress:  0.054
# Number of training circuits: 24   Number of validation circuits: 82   Number of test circuits: 81   Number of parameters in model: 205
# Progress:  0.056
# Number of training circuits: 25   Number of validation circuits: 82   Number of test circuits: 81   Number of parameters in model: 205
# Progress:  0.058
# Number of training circuits: 26   Number of validation circuits: 85   Number of test circuits: 86   Number of parameters in model: 208
# Progress:  0.06
# Number of training circuits: 27   Number of validation circuits: 88   Number of test circuits: 87   Number of parameters in model: 211
# Progress:  0.062
# Number of training circuits: 28   Number of validation circuits: 88   Number of test circuits: 87   Number of parameters in model: 211
# Progress:  0.065
# Number of training circuits: 29   Number of validation circuits: 88   Number of test circuits: 87   Number of parameters in model: 211
# Progress:  0.067
# Number of training circuits: 30   Number of validation circuits: 91   Number of test circuits: 89   Number of parameters in model: 217
# Progress:  0.069
# Number of training circuits: 31   Number of validation circuits: 91   Number of test circuits: 89   Number of parameters in model: 217
# Progress:  0.071
# Number of training circuits: 32   Number of validation circuits: 91   Number of test circuits: 89   Number of parameters in model: 217
# Progress:  0.074
# Number of training circuits: 33   Number of validation circuits: 91   Number of test circuits: 89   Number of parameters in model: 217
# Progress:  0.076
# Number of training circuits: 34   Number of validation circuits: 91   Number of test circuits: 89   Number of parameters in model: 217
# Progress:  0.078
# Number of training circuits: 35   Number of validation circuits: 92   Number of test circuits: 93   Number of parameters in model: 223
# Progress:  0.08
# Number of training circuits: 36   Number of validation circuits: 92   Number of test circuits: 93   Number of parameters in model: 223
# Progress:  0.083
# Number of training circuits: 37   Number of validation circuits: 92   Number of test circuits: 93   Number of parameters in model: 223
# Progress:  0.085
# Number of training circuits: 38   Number of validation circuits: 92   Number of test circuits: 93   Number of parameters in model: 223
# Progress:  0.087
# Number of training circuits: 39   Number of validation circuits: 96   Number of test circuits: 98   Number of parameters in model: 226
# 0.01 0.01
# Epoch: 200   train/loss: 9.6877   valid/loss: 25.57   train/acc: 0.1795   valid/acc: 0.1354
# Epoch: 400   train/loss: 9.5188   valid/loss: 25.1316   train/acc: 0.1282   valid/acc: 0.0625
# Epoch: 600   train/loss: 9.4876   valid/loss: 25.1808   train/acc: 0.1282   valid/acc: 0.1458
# Epoch: 800   train/loss: 9.4803   valid/loss: 25.1022   train/acc: 0.0769   valid/acc: 0.1667
# Epoch: 1000   train/loss: 9.4162   valid/loss: 25.0731   train/acc: 0.0769   valid/acc: 0.1042
# Epoch: 1200   train/loss: 9.3623   valid/loss: 25.1362   train/acc: 0.2051   valid/acc: 0.125
# Epoch: 1400   train/loss: 9.255   valid/loss: 24.9848   train/acc: 0.2051   valid/acc: 0.1667
# Epoch: 1600   train/loss: 9.2564   valid/loss: 24.9758   train/acc: 0.1795   valid/acc: 0.1562
# Epoch: 1800   train/loss: 9.1699   valid/loss: 24.8866   train/acc: 0.1538   valid/acc: 0.1354
# Epoch: 2000   train/loss: 9.0806   valid/loss: 24.8016   train/acc: 0.1538   valid/acc: 0.125
# Epoch: 2200   train/loss: 9.1408   valid/loss: 24.8455   train/acc: 0.2051   valid/acc: 0.1458
# Epoch: 2400   train/loss: 9.0168   valid/loss: 25.0417   train/acc: 0.2308   valid/acc: 0.1354
# Epoch: 2600   train/loss: 8.9588   valid/loss: 25.0644   train/acc: 0.1795   valid/acc: 0.1458
# Epoch: 2800   train/loss: 8.9372   valid/loss: 25.1193   train/acc: 0.1538   valid/acc: 0.125
# Epoch: 3000   train/loss: 9.0096   valid/loss: 25.3043   train/acc: 0.2308   valid/acc: 0.1042
# Epoch: 3200   train/loss: 8.9141   valid/loss: 25.3684   train/acc: 0.1282   valid/acc: 0.1771
# Epoch: 3400   train/loss: 8.9275   valid/loss: 25.3467   train/acc: 0.1538   valid/acc: 0.1354
# Epoch: 3600   train/loss: 8.9   valid/loss: 25.5003   train/acc: 0.2051   valid/acc: 0.0833
# Epoch: 3800   train/loss: 8.8062   valid/loss: 25.6175   train/acc: 0.1795   valid/acc: 0.1458
# Epoch: 4000   train/loss: 8.8805   valid/loss: 25.6591   train/acc: 0.2564   valid/acc: 0.1146
# Epoch: 4200   train/loss: 8.7499   valid/loss: 25.51   train/acc: 0.1795   valid/acc: 0.1146
# Epoch: 4400   train/loss: 8.64   valid/loss: 25.5334   train/acc: 0.2051   valid/acc: 0.1667
# Epoch: 4600   train/loss: 8.725   valid/loss: 25.3047   train/acc: 0.2308   valid/acc: 0.0729
# Epoch: 4800   train/loss: 8.6893   valid/loss: 25.4403   train/acc: 0.1795   valid/acc: 0.125
# Epoch: 5000   train/loss: 8.589   valid/loss: 25.782   train/acc: 0.2308   valid/acc: 0.1562
# Epoch: 5200   train/loss: 8.6315   valid/loss: 25.477   train/acc: 0.1282   valid/acc: 0.1354
# Epoch: 5400   train/loss: 8.6169   valid/loss: 25.9564   train/acc: 0.1795   valid/acc: 0.1771
# Epoch: 5600   train/loss: 8.614   valid/loss: 25.887   train/acc: 0.2051   valid/acc: 0.1042
# Epoch: 5800   train/loss: 8.5846   valid/loss: 25.8523   train/acc: 0.2051   valid/acc: 0.1979
# Epoch: 6000   train/loss: 8.5897   valid/loss: 25.8016   train/acc: 0.1795   valid/acc: 0.1146
# Epoch: 6200   train/loss: 8.4981   valid/loss: 26.0252   train/acc: 0.1282   valid/acc: 0.1146
# Epoch: 6400   train/loss: 8.4387   valid/loss: 25.9653   train/acc: 0.2308   valid/acc: 0.125
# Epoch: 6600   train/loss: 8.4666   valid/loss: 25.9088   train/acc: 0.2564   valid/acc: 0.125
# Epoch: 6800   train/loss: 8.4485   valid/loss: 25.8125   train/acc: 0.2564   valid/acc: 0.1146
# Epoch: 7000   train/loss: 8.4974   valid/loss: 25.7598   train/acc: 0.1538   valid/acc: 0.1354
# Epoch: 7200   train/loss: 8.443   valid/loss: 25.8021   train/acc: 0.2308   valid/acc: 0.0833
# Epoch: 7400   train/loss: 8.4339   valid/loss: 25.882   train/acc: 0.1795   valid/acc: 0.125
# Epoch: 7600   train/loss: 8.4282   valid/loss: 25.9551   train/acc: 0.1795   valid/acc: 0.1146
# Epoch: 7800   train/loss: 8.4066   valid/loss: 25.8653   train/acc: 0.1282   valid/acc: 0.1354
# Epoch: 8000   train/loss: 8.4089   valid/loss: 26.6027   train/acc: 0.2051   valid/acc: 0.0938
# Epoch: 8200   train/loss: 8.3755   valid/loss: 25.9078   train/acc: 0.2051   valid/acc: 0.1458
# Epoch: 8400   train/loss: 8.3781   valid/loss: 25.7738   train/acc: 0.1795   valid/acc: 0.1146
# Epoch: 8600   train/loss: 8.2607   valid/loss: 25.7518   train/acc: 0.1538   valid/acc: 0.1458
# Epoch: 8800   train/loss: 8.2407   valid/loss: 25.796   train/acc: 0.1282   valid/acc: 0.1458
# Epoch: 9000   train/loss: 8.2127   valid/loss: 25.6847   train/acc: 0.3077   valid/acc: 0.125
# Epoch: 9200   train/loss: 8.0942   valid/loss: 25.8013   train/acc: 0.1282   valid/acc: 0.0938
# Epoch: 9400   train/loss: 8.1585   valid/loss: 25.8268   train/acc: 0.1795   valid/acc: 0.0938
# Epoch: 9600   train/loss: 8.0866   valid/loss: 25.8852   train/acc: 0.2821   valid/acc: 0.0938
# Epoch: 9800   train/loss: 8.0242   valid/loss: 26.004   train/acc: 0.1795   valid/acc: 0.1042
# Epoch: 10000   train/loss: 8.0054   valid/loss: 26.1249   train/acc: 0.1282   valid/acc: 0.0938
# Test accuracy: 0.11224489795918367
# Progress:  0.089
# Number of training circuits: 40   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.092
# Number of training circuits: 41   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.094
# Number of training circuits: 42   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.096
# Number of training circuits: 43   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.098
# Number of training circuits: 44   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.1
# Number of training circuits: 45   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.103
# Number of training circuits: 46   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.105
# Number of training circuits: 47   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.107
# Number of training circuits: 48   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.109
# Number of training circuits: 49   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.112
# Number of training circuits: 50   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.114
# Number of training circuits: 51   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.116
# Number of training circuits: 52   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.118
# Number of training circuits: 53   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.121
# Number of training circuits: 54   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.123
# Number of training circuits: 55   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.125
# Number of training circuits: 56   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.127
# Number of training circuits: 57   Number of validation circuits: 99   Number of test circuits: 101   Number of parameters in model: 229
# Progress:  0.129
# Number of training circuits: 58   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.132
# Number of training circuits: 59   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# 0.01 0.01
# Epoch: 200   train/loss: 14.0222   valid/loss: 29.0362   train/acc: 0.2203   valid/acc: 0.1748
# Epoch: 400   train/loss: 13.2932   valid/loss: 29.1796   train/acc: 0.1864   valid/acc: 0.165
# Epoch: 600   train/loss: 12.9557   valid/loss: 29.5697   train/acc: 0.2373   valid/acc: 0.2039
# Epoch: 800   train/loss: 12.3827   valid/loss: 28.9938   train/acc: 0.3051   valid/acc: 0.165
# Epoch: 1000   train/loss: 11.969   valid/loss: 29.6674   train/acc: 0.2712   valid/acc: 0.2136
# Epoch: 1200   train/loss: 11.5874   valid/loss: 30.5886   train/acc: 0.2542   valid/acc: 0.165
# Epoch: 1400   train/loss: 11.2787   valid/loss: 30.6202   train/acc: 0.2373   valid/acc: 0.1359
# Epoch: 1600   train/loss: 11.0643   valid/loss: 31.4378   train/acc: 0.2203   valid/acc: 0.1456
# Epoch: 1800   train/loss: 10.8452   valid/loss: 32.0431   train/acc: 0.3559   valid/acc: 0.0874
# Epoch: 2000   train/loss: 10.9053   valid/loss: 32.93   train/acc: 0.339   valid/acc: 0.1068
# Epoch: 2200   train/loss: 10.8109   valid/loss: 33.1669   train/acc: 0.3559   valid/acc: 0.1359
# Epoch: 2400   train/loss: 10.7744   valid/loss: 33.6542   train/acc: 0.339   valid/acc: 0.1068
# Epoch: 2600   train/loss: 10.6906   valid/loss: 34.3775   train/acc: 0.339   valid/acc: 0.1262
# Epoch: 2800   train/loss: 10.6994   valid/loss: 32.9485   train/acc: 0.2203   valid/acc: 0.0971
# Epoch: 3000   train/loss: 10.4256   valid/loss: 33.5347   train/acc: 0.3051   valid/acc: 0.1068
# Epoch: 3200   train/loss: 10.5739   valid/loss: 33.4283   train/acc: 0.339   valid/acc: 0.1359
# Epoch: 3400   train/loss: 10.505   valid/loss: 33.0628   train/acc: 0.3559   valid/acc: 0.2039
# Epoch: 3600   train/loss: 10.3841   valid/loss: 35.6768   train/acc: 0.339   valid/acc: 0.1553
# Epoch: 3800   train/loss: 10.2646   valid/loss: 34.1984   train/acc: 0.2373   valid/acc: 0.1845
# Epoch: 4000   train/loss: 10.2581   valid/loss: 34.4601   train/acc: 0.339   valid/acc: 0.1165
# Epoch: 4200   train/loss: 10.3255   valid/loss: 35.7194   train/acc: 0.3051   valid/acc: 0.1262
# Epoch: 4400   train/loss: 10.1465   valid/loss: 34.4468   train/acc: 0.3051   valid/acc: 0.2039
# Epoch: 4600   train/loss: 10.1982   valid/loss: 33.8161   train/acc: 0.4068   valid/acc: 0.1165
# Epoch: 4800   train/loss: 10.2255   valid/loss: 34.506   train/acc: 0.3051   valid/acc: 0.1262
# Epoch: 5000   train/loss: 10.1057   valid/loss: 35.4998   train/acc: 0.2881   valid/acc: 0.0971
# Epoch: 5200   train/loss: 10.1501   valid/loss: 36.3726   train/acc: 0.3051   valid/acc: 0.1748
# Epoch: 5400   train/loss: 10.1115   valid/loss: 35.9051   train/acc: 0.3559   valid/acc: 0.1456
# Epoch: 5600   train/loss: 10.2382   valid/loss: 36.6672   train/acc: 0.339   valid/acc: 0.1359
# Epoch: 5800   train/loss: 10.1525   valid/loss: 35.516   train/acc: 0.3729   valid/acc: 0.1748
# Epoch: 6000   train/loss: 9.9573   valid/loss: 36.8589   train/acc: 0.4068   valid/acc: 0.1359
# Epoch: 6200   train/loss: 9.8922   valid/loss: 36.2501   train/acc: 0.2712   valid/acc: 0.1359
# Epoch: 6400   train/loss: 10.0035   valid/loss: 35.549   train/acc: 0.3898   valid/acc: 0.1262
# Epoch: 6600   train/loss: 9.8384   valid/loss: 36.1214   train/acc: 0.322   valid/acc: 0.0971
# Epoch: 6800   train/loss: 10.0662   valid/loss: 36.6059   train/acc: 0.322   valid/acc: 0.1553
# Epoch: 7000   train/loss: 9.9593   valid/loss: 36.2455   train/acc: 0.2712   valid/acc: 0.0971
# Epoch: 7200   train/loss: 10.0182   valid/loss: 36.4982   train/acc: 0.2542   valid/acc: 0.1748
# Epoch: 7400   train/loss: 10.0515   valid/loss: 35.8569   train/acc: 0.3898   valid/acc: 0.1748
# Epoch: 7600   train/loss: 9.8825   valid/loss: 36.8912   train/acc: 0.3729   valid/acc: 0.1262
# Epoch: 7800   train/loss: 9.9447   valid/loss: 35.1797   train/acc: 0.3729   valid/acc: 0.1359
# Epoch: 8000   train/loss: 9.9465   valid/loss: 35.6766   train/acc: 0.4068   valid/acc: 0.1359
# Epoch: 8200   train/loss: 9.788   valid/loss: 36.0306   train/acc: 0.3729   valid/acc: 0.1553
# Epoch: 8400   train/loss: 9.8908   valid/loss: 37.232   train/acc: 0.2373   valid/acc: 0.1553
# Epoch: 8600   train/loss: 9.912   valid/loss: 36.3446   train/acc: 0.2881   valid/acc: 0.1068
# Epoch: 8800   train/loss: 9.7898   valid/loss: 36.9432   train/acc: 0.322   valid/acc: 0.1553
# Epoch: 9000   train/loss: 9.8516   valid/loss: 37.4357   train/acc: 0.3051   valid/acc: 0.1359
# Epoch: 9200   train/loss: 9.7764   valid/loss: 36.7734   train/acc: 0.322   valid/acc: 0.1262
# Epoch: 9400   train/loss: 9.9749   valid/loss: 36.7237   train/acc: 0.2712   valid/acc: 0.068
# Epoch: 9600   train/loss: 9.7165   valid/loss: 37.1406   train/acc: 0.339   valid/acc: 0.1359
# Epoch: 9800   train/loss: 9.8042   valid/loss: 36.0736   train/acc: 0.322   valid/acc: 0.0874
# Epoch: 10000   train/loss: 9.8654   valid/loss: 37.3916   train/acc: 0.2712   valid/acc: 0.165
# Test accuracy: 0.12380952380952381
# Progress:  0.134
# Number of training circuits: 60   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.136
# Number of training circuits: 61   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.138
# Number of training circuits: 62   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.141
# Number of training circuits: 63   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.143
# Number of training circuits: 64   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.145
# Number of training circuits: 65   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.147
# Number of training circuits: 66   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.15
# Number of training circuits: 67   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.152
# Number of training circuits: 68   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.154
# Number of training circuits: 69   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.156
# Number of training circuits: 70   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.158
# Number of training circuits: 71   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.161
# Number of training circuits: 72   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.163
# Number of training circuits: 73   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.165
# Number of training circuits: 74   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.167
# Number of training circuits: 75   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.17
# Number of training circuits: 76   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.172
# Number of training circuits: 76   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.174
# Number of training circuits: 77   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.176
# Number of training circuits: 78   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# 0.01 0.01
# Epoch: 200   train/loss: 17.4533   valid/loss: 28.6365   train/acc: 0.2821   valid/acc: 0.1942
# Epoch: 400   train/loss: 16.1407   valid/loss: 29.4958   train/acc: 0.2564   valid/acc: 0.165
# Epoch: 600   train/loss: 15.6898   valid/loss: 30.5213   train/acc: 0.2308   valid/acc: 0.0971
# Epoch: 800   train/loss: 15.5314   valid/loss: 31.1438   train/acc: 0.3077   valid/acc: 0.1262
# Epoch: 1000   train/loss: 15.3676   valid/loss: 30.4607   train/acc: 0.2821   valid/acc: 0.1165
# Epoch: 1200   train/loss: 15.2189   valid/loss: 30.9211   train/acc: 0.2564   valid/acc: 0.0874
# Epoch: 1400   train/loss: 15.0988   valid/loss: 32.1522   train/acc: 0.2308   valid/acc: 0.1165
# Epoch: 1600   train/loss: 15.1909   valid/loss: 31.7293   train/acc: 0.3077   valid/acc: 0.1262
# Epoch: 1800   train/loss: 14.9583   valid/loss: 32.7858   train/acc: 0.2949   valid/acc: 0.1456
# Epoch: 2000   train/loss: 14.9997   valid/loss: 33.9716   train/acc: 0.359   valid/acc: 0.1553
# Epoch: 2200   train/loss: 14.8647   valid/loss: 34.0466   train/acc: 0.2564   valid/acc: 0.1165
# Epoch: 2400   train/loss: 14.8481   valid/loss: 33.5582   train/acc: 0.2308   valid/acc: 0.1165
# Epoch: 2600   train/loss: 14.9814   valid/loss: 33.1592   train/acc: 0.2308   valid/acc: 0.165
# Epoch: 2800   train/loss: 14.8072   valid/loss: 32.864   train/acc: 0.2692   valid/acc: 0.1262
# Epoch: 3000   train/loss: 14.81   valid/loss: 34.3252   train/acc: 0.2308   valid/acc: 0.165
# Epoch: 3200   train/loss: 14.8243   valid/loss: 33.6165   train/acc: 0.2692   valid/acc: 0.165
# Epoch: 3400   train/loss: 14.7729   valid/loss: 33.9237   train/acc: 0.2949   valid/acc: 0.165
# Epoch: 3600   train/loss: 14.744   valid/loss: 33.4453   train/acc: 0.2564   valid/acc: 0.1068
# Epoch: 3800   train/loss: 14.7705   valid/loss: 33.2446   train/acc: 0.2179   valid/acc: 0.165
# Epoch: 4000   train/loss: 14.7259   valid/loss: 32.9639   train/acc: 0.2949   valid/acc: 0.1262
# Epoch: 4200   train/loss: 14.758   valid/loss: 34.3092   train/acc: 0.3077   valid/acc: 0.1068
# Epoch: 4400   train/loss: 14.6362   valid/loss: 34.9466   train/acc: 0.2564   valid/acc: 0.068
# Epoch: 4600   train/loss: 14.6938   valid/loss: 33.8619   train/acc: 0.2436   valid/acc: 0.1553
# Epoch: 4800   train/loss: 14.5316   valid/loss: 34.0951   train/acc: 0.3205   valid/acc: 0.1553
# Epoch: 5000   train/loss: 14.6424   valid/loss: 33.4876   train/acc: 0.2949   valid/acc: 0.0583
# Epoch: 5200   train/loss: 14.5229   valid/loss: 33.3402   train/acc: 0.2308   valid/acc: 0.1262
# Epoch: 5400   train/loss: 14.5573   valid/loss: 33.7381   train/acc: 0.2949   valid/acc: 0.1359
# Epoch: 5600   train/loss: 14.6274   valid/loss: 33.6948   train/acc: 0.2179   valid/acc: 0.1748
# Epoch: 5800   train/loss: 14.4872   valid/loss: 33.4396   train/acc: 0.2692   valid/acc: 0.1456
# Epoch: 6000   train/loss: 14.4957   valid/loss: 33.6888   train/acc: 0.3205   valid/acc: 0.1262
# Epoch: 6200   train/loss: 14.4135   valid/loss: 35.0519   train/acc: 0.3205   valid/acc: 0.1068
# Epoch: 6400   train/loss: 14.5294   valid/loss: 33.3628   train/acc: 0.2949   valid/acc: 0.165
# Epoch: 6600   train/loss: 14.4879   valid/loss: 33.7399   train/acc: 0.2564   valid/acc: 0.1553
# Epoch: 6800   train/loss: 14.4922   valid/loss: 33.9737   train/acc: 0.2821   valid/acc: 0.1748
# Epoch: 7000   train/loss: 14.4912   valid/loss: 33.5826   train/acc: 0.2564   valid/acc: 0.165
# Epoch: 7200   train/loss: 14.4549   valid/loss: 32.8686   train/acc: 0.2692   valid/acc: 0.1165
# Epoch: 7400   train/loss: 14.3437   valid/loss: 34.3726   train/acc: 0.2692   valid/acc: 0.1456
# Epoch: 7600   train/loss: 14.3405   valid/loss: 34.6555   train/acc: 0.2564   valid/acc: 0.1748
# Epoch: 7800   train/loss: 14.6195   valid/loss: 34.4908   train/acc: 0.2564   valid/acc: 0.1942
# Epoch: 8000   train/loss: 14.2791   valid/loss: 34.5734   train/acc: 0.2564   valid/acc: 0.165
# Epoch: 8200   train/loss: 14.3694   valid/loss: 34.0574   train/acc: 0.2436   valid/acc: 0.2039
# Epoch: 8400   train/loss: 14.2894   valid/loss: 34.7709   train/acc: 0.2949   valid/acc: 0.1262
# Epoch: 8600   train/loss: 14.3341   valid/loss: 33.5742   train/acc: 0.2564   valid/acc: 0.1165
# Epoch: 8800   train/loss: 14.374   valid/loss: 35.0112   train/acc: 0.2564   valid/acc: 0.1456
# Epoch: 9000   train/loss: 14.1906   valid/loss: 34.3035   train/acc: 0.2564   valid/acc: 0.1942
# Epoch: 9200   train/loss: 14.2539   valid/loss: 33.6176   train/acc: 0.2821   valid/acc: 0.1359
# Epoch: 9400   train/loss: 14.3185   valid/loss: 33.1875   train/acc: 0.2179   valid/acc: 0.1456
# Epoch: 9600   train/loss: 14.4381   valid/loss: 33.22   train/acc: 0.2692   valid/acc: 0.1748
# Epoch: 9800   train/loss: 14.2238   valid/loss: 34.2167   train/acc: 0.2949   valid/acc: 0.165
# Epoch: 10000   train/loss: 14.2075   valid/loss: 33.996   train/acc: 0.2949   valid/acc: 0.1165
# Test accuracy: 0.11428571428571428
# Progress:  0.179
# Number of training circuits: 79   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.181
# Number of training circuits: 80   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.183
# Number of training circuits: 81   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.185
# Number of training circuits: 82   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.188
# Number of training circuits: 83   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.19
# Number of training circuits: 84   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.192
# Number of training circuits: 85   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.194
# Number of training circuits: 86   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.196
# Number of training circuits: 87   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.199
# Number of training circuits: 88   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.201
# Number of training circuits: 89   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.203
# Number of training circuits: 90   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.205
# Number of training circuits: 91   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.208
# Number of training circuits: 92   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.21
# Number of training circuits: 93   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.212
# Number of training circuits: 94   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.214
# Number of training circuits: 95   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.217
# Number of training circuits: 96   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.219
# Number of training circuits: 96   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.221
# Number of training circuits: 97   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# 0.01 0.01
# Epoch: 200   train/loss: 22.5611   valid/loss: 28.176   train/acc: 0.2062   valid/acc: 0.1456
# Epoch: 400   train/loss: 21.2931   valid/loss: 29.1468   train/acc: 0.2887   valid/acc: 0.0971
# Epoch: 600   train/loss: 20.2857   valid/loss: 30.666   train/acc: 0.2474   valid/acc: 0.165
# Epoch: 800   train/loss: 20.0066   valid/loss: 32.2064   train/acc: 0.2062   valid/acc: 0.1456
# Epoch: 1000   train/loss: 19.5923   valid/loss: 30.6727   train/acc: 0.2371   valid/acc: 0.1553
# Epoch: 1200   train/loss: 19.3822   valid/loss: 32.5906   train/acc: 0.3093   valid/acc: 0.1359
# Epoch: 1400   train/loss: 19.2702   valid/loss: 31.9318   train/acc: 0.3093   valid/acc: 0.1068
# Epoch: 1600   train/loss: 19.2783   valid/loss: 31.7875   train/acc: 0.2784   valid/acc: 0.1748
# Epoch: 1800   train/loss: 19.1652   valid/loss: 32.1961   train/acc: 0.2784   valid/acc: 0.1262
# Epoch: 2000   train/loss: 19.0105   valid/loss: 31.5783   train/acc: 0.2268   valid/acc: 0.1262
# Epoch: 2200   train/loss: 18.9828   valid/loss: 31.8966   train/acc: 0.2371   valid/acc: 0.1262
# Epoch: 2400   train/loss: 18.9121   valid/loss: 32.085   train/acc: 0.299   valid/acc: 0.1359
# Epoch: 2600   train/loss: 18.8714   valid/loss: 31.708   train/acc: 0.2784   valid/acc: 0.1068
# Epoch: 2800   train/loss: 18.8934   valid/loss: 32.421   train/acc: 0.268   valid/acc: 0.1456
# Epoch: 3000   train/loss: 18.6978   valid/loss: 31.5173   train/acc: 0.2268   valid/acc: 0.1262
# Epoch: 3200   train/loss: 18.7965   valid/loss: 31.793   train/acc: 0.2474   valid/acc: 0.0777
# Epoch: 3400   train/loss: 18.841   valid/loss: 31.8928   train/acc: 0.299   valid/acc: 0.1262
# Epoch: 3600   train/loss: 18.7247   valid/loss: 32.1905   train/acc: 0.2887   valid/acc: 0.1262
# Epoch: 3800   train/loss: 18.8066   valid/loss: 32.2936   train/acc: 0.2474   valid/acc: 0.1553
# Epoch: 4000   train/loss: 18.7734   valid/loss: 32.4521   train/acc: 0.2371   valid/acc: 0.1165
# Epoch: 4200   train/loss: 18.617   valid/loss: 32.3048   train/acc: 0.2577   valid/acc: 0.1748
# Epoch: 4400   train/loss: 18.6503   valid/loss: 32.6735   train/acc: 0.2784   valid/acc: 0.1165
# Epoch: 4600   train/loss: 18.6944   valid/loss: 32.4832   train/acc: 0.299   valid/acc: 0.1456
# Epoch: 4800   train/loss: 18.6002   valid/loss: 32.4516   train/acc: 0.2784   valid/acc: 0.1262
# Epoch: 5000   train/loss: 18.6983   valid/loss: 32.8879   train/acc: 0.2887   valid/acc: 0.1262
# Epoch: 5200   train/loss: 18.6345   valid/loss: 32.4363   train/acc: 0.2887   valid/acc: 0.1359
# Epoch: 5400   train/loss: 18.659   valid/loss: 32.6567   train/acc: 0.2577   valid/acc: 0.2136
# Epoch: 5600   train/loss: 18.5844   valid/loss: 32.6936   train/acc: 0.268   valid/acc: 0.1456
# Epoch: 5800   train/loss: 18.6248   valid/loss: 32.0319   train/acc: 0.3505   valid/acc: 0.1262
# Epoch: 6000   train/loss: 18.5932   valid/loss: 32.8609   train/acc: 0.3505   valid/acc: 0.2039
# Epoch: 6200   train/loss: 18.6722   valid/loss: 32.3659   train/acc: 0.2268   valid/acc: 0.1262
# Epoch: 6400   train/loss: 18.7049   valid/loss: 32.8203   train/acc: 0.2577   valid/acc: 0.0874
# Epoch: 6600   train/loss: 18.5469   valid/loss: 33.5144   train/acc: 0.2887   valid/acc: 0.1845
# Epoch: 6800   train/loss: 18.5266   valid/loss: 33.1572   train/acc: 0.2474   valid/acc: 0.1553
# Epoch: 7000   train/loss: 18.5545   valid/loss: 33.4132   train/acc: 0.2371   valid/acc: 0.1553
# Epoch: 7200   train/loss: 18.6392   valid/loss: 32.7373   train/acc: 0.268   valid/acc: 0.1748
# Epoch: 7400   train/loss: 18.5191   valid/loss: 32.949   train/acc: 0.3505   valid/acc: 0.165
# Epoch: 7600   train/loss: 18.5134   valid/loss: 32.8092   train/acc: 0.3608   valid/acc: 0.1845
# Epoch: 7800   train/loss: 18.4521   valid/loss: 33.3306   train/acc: 0.2887   valid/acc: 0.165
# Epoch: 8000   train/loss: 18.5297   valid/loss: 32.5796   train/acc: 0.3402   valid/acc: 0.1845
# Epoch: 8200   train/loss: 18.6009   valid/loss: 32.9738   train/acc: 0.2062   valid/acc: 0.2136
# Epoch: 8400   train/loss: 18.5768   valid/loss: 33.2484   train/acc: 0.3299   valid/acc: 0.1165
# Epoch: 8600   train/loss: 18.4572   valid/loss: 32.9389   train/acc: 0.2474   valid/acc: 0.1942
# Epoch: 8800   train/loss: 18.5184   valid/loss: 33.0759   train/acc: 0.2474   valid/acc: 0.1748
# Epoch: 9000   train/loss: 18.4545   valid/loss: 32.6678   train/acc: 0.299   valid/acc: 0.2039
# Epoch: 9200   train/loss: 18.4095   valid/loss: 33.033   train/acc: 0.3299   valid/acc: 0.1456
# Epoch: 9400   train/loss: 18.4418   valid/loss: 33.0033   train/acc: 0.3093   valid/acc: 0.1359
# Epoch: 9600   train/loss: 18.6004   valid/loss: 33.3138   train/acc: 0.268   valid/acc: 0.1748
# Epoch: 9800   train/loss: 18.4781   valid/loss: 32.881   train/acc: 0.2371   valid/acc: 0.1942
# Epoch: 10000   train/loss: 18.5356   valid/loss: 33.0307   train/acc: 0.3093   valid/acc: 0.1845
# Test accuracy: 0.1523809523809524
# Progress:  0.223
# Number of training circuits: 98   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 232
# Progress:  0.225
# Number of training circuits: 99   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.228
# Number of training circuits: 100   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.23
# Number of training circuits: 101   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.232
# Number of training circuits: 102   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.234
# Number of training circuits: 103   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.237
# Number of training circuits: 104   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.239
# Number of training circuits: 105   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.241
# Number of training circuits: 106   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.243
# Number of training circuits: 107   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.246
# Number of training circuits: 108   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.248
# Number of training circuits: 109   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.25
# Number of training circuits: 110   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.252
# Number of training circuits: 111   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.254
# Number of training circuits: 112   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.257
# Number of training circuits: 113   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.259
# Number of training circuits: 114   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.261
# Number of training circuits: 115   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.263
# Number of training circuits: 116   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.266
# Number of training circuits: 117   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# 0.01 0.01
# Epoch: 200   train/loss: 28.9871   valid/loss: 26.311   train/acc: 0.1624   valid/acc: 0.2136
# Epoch: 400   train/loss: 28.756   valid/loss: 26.6423   train/acc: 0.1538   valid/acc: 0.1748
# Epoch: 600   train/loss: 28.6498   valid/loss: 26.4767   train/acc: 0.1282   valid/acc: 0.2233
# Epoch: 800   train/loss: 28.5481   valid/loss: 26.4528   train/acc: 0.1111   valid/acc: 0.1262
# Epoch: 1000   train/loss: 28.3561   valid/loss: 26.6394   train/acc: 0.1709   valid/acc: 0.2039
# Epoch: 1200   train/loss: 28.2456   valid/loss: 26.704   train/acc: 0.1709   valid/acc: 0.1553
# Epoch: 1400   train/loss: 28.1803   valid/loss: 26.8559   train/acc: 0.1453   valid/acc: 0.1456
# Epoch: 1600   train/loss: 28.1324   valid/loss: 27.0787   train/acc: 0.1453   valid/acc: 0.2039
# Epoch: 1800   train/loss: 28.1107   valid/loss: 26.7174   train/acc: 0.1709   valid/acc: 0.165
# Epoch: 2000   train/loss: 27.9816   valid/loss: 26.7772   train/acc: 0.1624   valid/acc: 0.1165
# Epoch: 2200   train/loss: 27.891   valid/loss: 26.7881   train/acc: 0.1538   valid/acc: 0.1165
# Epoch: 2400   train/loss: 27.7876   valid/loss: 27.2364   train/acc: 0.1368   valid/acc: 0.1359
# Epoch: 2600   train/loss: 27.7002   valid/loss: 27.2835   train/acc: 0.1453   valid/acc: 0.1359
# Epoch: 2800   train/loss: 27.6079   valid/loss: 27.217   train/acc: 0.1966   valid/acc: 0.165
# Epoch: 3000   train/loss: 27.4608   valid/loss: 27.405   train/acc: 0.2137   valid/acc: 0.1456
# Epoch: 3200   train/loss: 27.5135   valid/loss: 27.1435   train/acc: 0.1709   valid/acc: 0.0971
# Epoch: 3400   train/loss: 27.4719   valid/loss: 27.1865   train/acc: 0.1966   valid/acc: 0.1359
# Epoch: 3600   train/loss: 27.2956   valid/loss: 27.3685   train/acc: 0.1795   valid/acc: 0.0971
# Epoch: 3800   train/loss: 27.2793   valid/loss: 27.6817   train/acc: 0.2051   valid/acc: 0.1942
# Epoch: 4000   train/loss: 27.1507   valid/loss: 27.4403   train/acc: 0.2222   valid/acc: 0.1359
# Epoch: 4200   train/loss: 27.2101   valid/loss: 27.4318   train/acc: 0.188   valid/acc: 0.1165
# Epoch: 4400   train/loss: 27.2122   valid/loss: 27.6031   train/acc: 0.1966   valid/acc: 0.1068
# Epoch: 4600   train/loss: 27.1491   valid/loss: 27.5328   train/acc: 0.2479   valid/acc: 0.1068
# Epoch: 4800   train/loss: 27.1347   valid/loss: 28.0738   train/acc: 0.188   valid/acc: 0.1553
# Epoch: 5000   train/loss: 27.0682   valid/loss: 27.954   train/acc: 0.1966   valid/acc: 0.1068
# Epoch: 5200   train/loss: 27.009   valid/loss: 27.8515   train/acc: 0.2137   valid/acc: 0.0971
# Epoch: 5400   train/loss: 26.9377   valid/loss: 27.9278   train/acc: 0.1538   valid/acc: 0.2039
# Epoch: 5600   train/loss: 26.9484   valid/loss: 28.176   train/acc: 0.1795   valid/acc: 0.1456
# Epoch: 5800   train/loss: 26.9988   valid/loss: 28.1163   train/acc: 0.2051   valid/acc: 0.1553
# Epoch: 6000   train/loss: 26.8691   valid/loss: 28.072   train/acc: 0.1966   valid/acc: 0.1553
# Epoch: 6200   train/loss: 26.8559   valid/loss: 27.9697   train/acc: 0.2308   valid/acc: 0.1553
# Epoch: 6400   train/loss: 26.8235   valid/loss: 28.1642   train/acc: 0.2051   valid/acc: 0.1068
# Epoch: 6600   train/loss: 26.697   valid/loss: 28.0881   train/acc: 0.2564   valid/acc: 0.165
# Epoch: 6800   train/loss: 26.4797   valid/loss: 28.046   train/acc: 0.2137   valid/acc: 0.068
# Epoch: 7000   train/loss: 26.2318   valid/loss: 28.234   train/acc: 0.1197   valid/acc: 0.165
# Epoch: 7200   train/loss: 26.2738   valid/loss: 28.4308   train/acc: 0.2051   valid/acc: 0.1553
# Epoch: 7400   train/loss: 26.116   valid/loss: 28.5761   train/acc: 0.2393   valid/acc: 0.1359
# Epoch: 7600   train/loss: 26.2485   valid/loss: 28.366   train/acc: 0.2393   valid/acc: 0.1456
# Epoch: 7800   train/loss: 25.8268   valid/loss: 28.6776   train/acc: 0.2479   valid/acc: 0.1359
# Epoch: 8000   train/loss: 25.7558   valid/loss: 28.8857   train/acc: 0.2564   valid/acc: 0.1359
# Epoch: 8200   train/loss: 25.7155   valid/loss: 29.0196   train/acc: 0.188   valid/acc: 0.1359
# Epoch: 8400   train/loss: 25.8066   valid/loss: 29.1319   train/acc: 0.2564   valid/acc: 0.1359
# Epoch: 8600   train/loss: 25.6639   valid/loss: 28.8971   train/acc: 0.2222   valid/acc: 0.1068
# Epoch: 8800   train/loss: 25.6867   valid/loss: 29.1806   train/acc: 0.2137   valid/acc: 0.1262
# Epoch: 9000   train/loss: 25.4999   valid/loss: 29.2777   train/acc: 0.1966   valid/acc: 0.1262
# Epoch: 9200   train/loss: 25.5348   valid/loss: 29.4321   train/acc: 0.2222   valid/acc: 0.1359
# Epoch: 9400   train/loss: 25.6192   valid/loss: 29.5857   train/acc: 0.188   valid/acc: 0.1456
# Epoch: 9600   train/loss: 25.4882   valid/loss: 29.455   train/acc: 0.2564   valid/acc: 0.1845
# Epoch: 9800   train/loss: 25.4864   valid/loss: 29.4664   train/acc: 0.1709   valid/acc: 0.1165
# Epoch: 10000   train/loss: 25.4622   valid/loss: 29.1875   train/acc: 0.1966   valid/acc: 0.1165
# Test accuracy: 0.10476190476190476
# Progress:  0.268
# Number of training circuits: 118   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.27
# Number of training circuits: 119   Number of validation circuits: 103   Number of test circuits: 105   Number of parameters in model: 235
# Progress:  0.272
# Number of training circuits: 120   Number of validation circuits: 104   Number of test circuits: 106   Number of parameters in model: 238
# Progress:  0.275
# Number of training circuits: 121   Number of validation circuits: 104   Number of test circuits: 106   Number of parameters in model: 238
# Progress:  0.277
# Number of training circuits: 122   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.279
# Number of training circuits: 123   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.281
# Number of training circuits: 124   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.283
# Number of training circuits: 125   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.286
# Number of training circuits: 126   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.288
# Number of training circuits: 127   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.29
# Number of training circuits: 128   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.292
# Number of training circuits: 129   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.295
# Number of training circuits: 130   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.297
# Number of training circuits: 131   Number of validation circuits: 105   Number of test circuits: 106   Number of parameters in model: 247
# Progress:  0.299
# Number of training circuits: 132   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# Progress:  0.301
# Number of training circuits: 133   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# Progress:  0.304
# Number of training circuits: 134   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# Progress:  0.306
# Number of training circuits: 135   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# Progress:  0.308
# Number of training circuits: 136   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# Progress:  0.31
# Number of training circuits: 137   Number of validation circuits: 106   Number of test circuits: 107   Number of parameters in model: 262
# 0.01 0.01
# Epoch: 200   train/loss: 33.8967   valid/loss: 29.3352   train/acc: 0.1606   valid/acc: 0.0943
# Epoch: 400   train/loss: 33.0873   valid/loss: 29.5578   train/acc: 0.1679   valid/acc: 0.1509
# Epoch: 600   train/loss: 32.5744   valid/loss: 32.3647   train/acc: 0.146   valid/acc: 0.1226
# Epoch: 800   train/loss: 32.2115   valid/loss: 31.191   train/acc: 0.1606   valid/acc: 0.1321
# Epoch: 1000   train/loss: 31.9014   valid/loss: 31.0429   train/acc: 0.2117   valid/acc: 0.0755
# Epoch: 1200   train/loss: 31.7731   valid/loss: 32.273   train/acc: 0.2044   valid/acc: 0.1226
# Epoch: 1400   train/loss: 31.7268   valid/loss: 30.5226   train/acc: 0.2336   valid/acc: 0.1132
# Epoch: 1600   train/loss: 31.5217   valid/loss: 30.8287   train/acc: 0.1971   valid/acc: 0.1321
# Epoch: 1800   train/loss: 31.4767   valid/loss: 30.5329   train/acc: 0.1971   valid/acc: 0.1509
# ...
# Progress:  0.911
# Number of training circuits: 401   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.913
# Number of training circuits: 402   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.915
# Number of training circuits: 403   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.917
# Number of training circuits: 404   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.92
# Number of training circuits: 405   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.922
# Number of training circuits: 406   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.924
# Number of training circuits: 407   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.926
# Number of training circuits: 408   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.929
# Number of training circuits: 409   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.931
# Number of training circuits: 410   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.933
# Number of training circuits: 411   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.935
# Number of training circuits: 412   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# 0.01 0.01
# Epoch: 200   train/loss: 106.1673   valid/loss: 28.526   train/acc: 0.1189   valid/acc: 0.0833
# Epoch: 400   train/loss: 105.5994   valid/loss: 27.8406   train/acc: 0.1408   valid/acc: 0.0741
# Epoch: 600   train/loss: 104.6504   valid/loss: 28.5947   train/acc: 0.1286   valid/acc: 0.1759
# Epoch: 800   train/loss: 104.1727   valid/loss: 28.985   train/acc: 0.1602   valid/acc: 0.1296
# Epoch: 1000   train/loss: 104.0246   valid/loss: 28.1682   train/acc: 0.1408   valid/acc: 0.1204
# Epoch: 1200   train/loss: 101.8043   valid/loss: 28.4897   train/acc: 0.1505   valid/acc: 0.1204
# Epoch: 1400   train/loss: 100.6765   valid/loss: 28.7826   train/acc: 0.1917   valid/acc: 0.1296
# Epoch: 1600   train/loss: 100.3772   valid/loss: 27.9104   train/acc: 0.199   valid/acc: 0.1944
# Epoch: 1800   train/loss: 99.4737   valid/loss: 27.9215   train/acc: 0.1942   valid/acc: 0.1574
# Epoch: 2000   train/loss: 99.5207   valid/loss: 27.9266   train/acc: 0.1893   valid/acc: 0.1019
# Epoch: 2200   train/loss: 98.5947   valid/loss: 28.2849   train/acc: 0.1966   valid/acc: 0.0833
# Epoch: 2400   train/loss: 98.2827   valid/loss: 28.2249   train/acc: 0.2184   valid/acc: 0.1481
# Epoch: 2600   train/loss: 97.7502   valid/loss: 28.091   train/acc: 0.2257   valid/acc: 0.1389
# Epoch: 2800   train/loss: 97.4762   valid/loss: 28.2149   train/acc: 0.1772   valid/acc: 0.1204
# Epoch: 3000   train/loss: 97.4496   valid/loss: 27.9962   train/acc: 0.1942   valid/acc: 0.1852
# Epoch: 3200   train/loss: 97.274   valid/loss: 27.9373   train/acc: 0.216   valid/acc: 0.1574
# Epoch: 3400   train/loss: 97.0205   valid/loss: 27.9441   train/acc: 0.2184   valid/acc: 0.1296
# Epoch: 3600   train/loss: 96.932   valid/loss: 28.122   train/acc: 0.199   valid/acc: 0.1111
# Epoch: 3800   train/loss: 96.8819   valid/loss: 27.9075   train/acc: 0.2136   valid/acc: 0.0926
# Epoch: 4000   train/loss: 96.6014   valid/loss: 27.9156   train/acc: 0.2257   valid/acc: 0.1204
# Epoch: 4200   train/loss: 96.4462   valid/loss: 28.1786   train/acc: 0.2354   valid/acc: 0.1204
# Epoch: 4400   train/loss: 96.2678   valid/loss: 28.0887   train/acc: 0.2524   valid/acc: 0.1667
# Epoch: 4600   train/loss: 95.931   valid/loss: 27.7438   train/acc: 0.199   valid/acc: 0.0833
# Epoch: 4800   train/loss: 95.9551   valid/loss: 28.31   train/acc: 0.2306   valid/acc: 0.0741
# Epoch: 5000   train/loss: 95.923   valid/loss: 28.1013   train/acc: 0.1893   valid/acc: 0.1481
# Epoch: 5200   train/loss: 96.5602   valid/loss: 28.3498   train/acc: 0.2282   valid/acc: 0.1296
# Epoch: 5400   train/loss: 96.3338   valid/loss: 28.1839   train/acc: 0.2306   valid/acc: 0.1667
# Epoch: 5600   train/loss: 95.8639   valid/loss: 28.57   train/acc: 0.2063   valid/acc: 0.0833
# Epoch: 5800   train/loss: 95.9831   valid/loss: 28.5078   train/acc: 0.2379   valid/acc: 0.1852
# Epoch: 6000   train/loss: 97.4475   valid/loss: 28.5974   train/acc: 0.2233   valid/acc: 0.1944
# Epoch: 6200   train/loss: 95.8634   valid/loss: 28.4639   train/acc: 0.1772   valid/acc: 0.1389
# Epoch: 6400   train/loss: 95.3568   valid/loss: 28.7059   train/acc: 0.2112   valid/acc: 0.1759
# Epoch: 6600   train/loss: 95.6618   valid/loss: 28.4106   train/acc: 0.2573   valid/acc: 0.1204
# Epoch: 6800   train/loss: 95.3829   valid/loss: 28.559   train/acc: 0.2257   valid/acc: 0.1759
# Epoch: 7000   train/loss: 95.0603   valid/loss: 28.5393   train/acc: 0.1893   valid/acc: 0.1019
# Epoch: 7200   train/loss: 94.7814   valid/loss: 28.6053   train/acc: 0.2184   valid/acc: 0.1204
# Epoch: 7400   train/loss: 94.9644   valid/loss: 28.4319   train/acc: 0.2451   valid/acc: 0.1759
# Epoch: 7600   train/loss: 94.6701   valid/loss: 28.6908   train/acc: 0.2549   valid/acc: 0.0926
# Epoch: 7800   train/loss: 94.4555   valid/loss: 28.8569   train/acc: 0.2209   valid/acc: 0.1759
# Epoch: 8000   train/loss: 94.533   valid/loss: 28.7379   train/acc: 0.2476   valid/acc: 0.1111
# Epoch: 8200   train/loss: 94.2911   valid/loss: 28.6715   train/acc: 0.2087   valid/acc: 0.1204
# Epoch: 8400   train/loss: 94.2565   valid/loss: 28.6385   train/acc: 0.2136   valid/acc: 0.1204
# Epoch: 8600   train/loss: 94.5236   valid/loss: 28.9689   train/acc: 0.2015   valid/acc: 0.1296
# Epoch: 8800   train/loss: 94.5588   valid/loss: 28.4826   train/acc: 0.2257   valid/acc: 0.1389
# Epoch: 9000   train/loss: 94.5163   valid/loss: 28.6176   train/acc: 0.2379   valid/acc: 0.1204
# Epoch: 9200   train/loss: 94.2263   valid/loss: 28.6165   train/acc: 0.2306   valid/acc: 0.0926
# Epoch: 9400   train/loss: 93.9689   valid/loss: 28.6415   train/acc: 0.2476   valid/acc: 0.1296
# Epoch: 9600   train/loss: 93.9196   valid/loss: 28.5833   train/acc: 0.233   valid/acc: 0.1667
# Epoch: 9800   train/loss: 93.9276   valid/loss: 28.4924   train/acc: 0.2112   valid/acc: 0.1019
# Epoch: 10000   train/loss: 93.7814   valid/loss: 28.532   train/acc: 0.2354   valid/acc: 0.1667
# Test accuracy: 0.2018348623853211
# Progress:  0.938
# Number of training circuits: 413   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.94
# Number of training circuits: 414   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.942
# Number of training circuits: 415   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.944
# Number of training circuits: 416   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.946
# Number of training circuits: 417   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.949
# Number of training circuits: 418   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.951
# Number of training circuits: 419   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.953
# Number of training circuits: 420   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.955
# Number of training circuits: 421   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.958
# Number of training circuits: 422   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.96
# Number of training circuits: 423   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.962
# Number of training circuits: 424   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.964
# Number of training circuits: 425   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.967
# Number of training circuits: 426   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.969
# Number of training circuits: 427   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.971
# Number of training circuits: 428   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.973
# Number of training circuits: 429   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.975
# Number of training circuits: 430   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.978
# Number of training circuits: 431   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.98
# Number of training circuits: 432   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# 0.01 0.01
# Epoch: 200   train/loss: 110.5083   valid/loss: 28.0323   train/acc: 0.1806   valid/acc: 0.0833
# Epoch: 400   train/loss: 111.1682   valid/loss: 28.2582   train/acc: 0.1713   valid/acc: 0.0648
# Epoch: 600   train/loss: 110.8899   valid/loss: 28.2747   train/acc: 0.169   valid/acc: 0.1019
# Epoch: 800   train/loss: 108.7892   valid/loss: 28.4986   train/acc: 0.2037   valid/acc: 0.1111
# Epoch: 1000   train/loss: 108.0885   valid/loss: 28.5668   train/acc: 0.1852   valid/acc: 0.1019
# Epoch: 1200   train/loss: 106.6384   valid/loss: 28.2098   train/acc: 0.1991   valid/acc: 0.1296
# Epoch: 1400   train/loss: 105.8039   valid/loss: 28.5586   train/acc: 0.1968   valid/acc: 0.1111
# Epoch: 1600   train/loss: 104.798   valid/loss: 28.2724   train/acc: 0.1921   valid/acc: 0.1481
# Epoch: 1800   train/loss: 105.6325   valid/loss: 29.2514   train/acc: 0.1991   valid/acc: 0.1204
# Epoch: 2000   train/loss: 103.6773   valid/loss: 28.4378   train/acc: 0.2153   valid/acc: 0.1481
# Epoch: 2200   train/loss: 103.8247   valid/loss: 28.7515   train/acc: 0.1644   valid/acc: 0.1667
# Epoch: 2400   train/loss: 106.1445   valid/loss: 28.5687   train/acc: 0.1852   valid/acc: 0.1759
# Epoch: 2600   train/loss: 105.1363   valid/loss: 29.0463   train/acc: 0.1898   valid/acc: 0.1389
# Epoch: 2800   train/loss: 103.7352   valid/loss: 28.5912   train/acc: 0.2199   valid/acc: 0.1019
# Epoch: 3000   train/loss: 103.0455   valid/loss: 29.7855   train/acc: 0.2245   valid/acc: 0.1296
# Epoch: 3200   train/loss: 102.5246   valid/loss: 29.13   train/acc: 0.1921   valid/acc: 0.1111
# Epoch: 3400   train/loss: 102.4854   valid/loss: 29.2681   train/acc: 0.1782   valid/acc: 0.1111
# Epoch: 3600   train/loss: 104.6692   valid/loss: 29.9305   train/acc: 0.213   valid/acc: 0.1852
# Epoch: 3800   train/loss: 102.3709   valid/loss: 30.1407   train/acc: 0.1644   valid/acc: 0.0648
# Epoch: 4000   train/loss: 102.069   valid/loss: 29.429   train/acc: 0.213   valid/acc: 0.1111
# Epoch: 4200   train/loss: 101.3803   valid/loss: 29.221   train/acc: 0.2292   valid/acc: 0.1296
# Epoch: 4400   train/loss: 101.258   valid/loss: 29.4272   train/acc: 0.2292   valid/acc: 0.1296
# Epoch: 4600   train/loss: 101.2694   valid/loss: 29.443   train/acc: 0.2292   valid/acc: 0.1944
# Epoch: 4800   train/loss: 100.6778   valid/loss: 29.3306   train/acc: 0.2014   valid/acc: 0.0648
# Epoch: 5000   train/loss: 100.9199   valid/loss: 29.171   train/acc: 0.2245   valid/acc: 0.1296
# Epoch: 5200   train/loss: 100.3605   valid/loss: 29.3082   train/acc: 0.1875   valid/acc: 0.1852
# Epoch: 5400   train/loss: 100.218   valid/loss: 29.352   train/acc: 0.2199   valid/acc: 0.1019
# Epoch: 5600   train/loss: 99.8956   valid/loss: 29.1653   train/acc: 0.2407   valid/acc: 0.1389
# Epoch: 5800   train/loss: 99.9356   valid/loss: 28.9808   train/acc: 0.2315   valid/acc: 0.1481
# Epoch: 6000   train/loss: 100.3947   valid/loss: 28.8036   train/acc: 0.2361   valid/acc: 0.1296
# Epoch: 6200   train/loss: 99.9953   valid/loss: 28.5891   train/acc: 0.2315   valid/acc: 0.1389
# Epoch: 6400   train/loss: 99.6589   valid/loss: 29.0639   train/acc: 0.2292   valid/acc: 0.1759
# Epoch: 6600   train/loss: 99.5166   valid/loss: 28.9081   train/acc: 0.2454   valid/acc: 0.1389
# Epoch: 6800   train/loss: 99.4166   valid/loss: 29.3179   train/acc: 0.2245   valid/acc: 0.1481
# Epoch: 7000   train/loss: 99.0387   valid/loss: 29.2141   train/acc: 0.2361   valid/acc: 0.1667
# Epoch: 7200   train/loss: 99.0068   valid/loss: 29.1282   train/acc: 0.2384   valid/acc: 0.1204
# Epoch: 7400   train/loss: 99.1506   valid/loss: 29.323   train/acc: 0.2593   valid/acc: 0.1296
# Epoch: 7600   train/loss: 98.875   valid/loss: 29.1153   train/acc: 0.2222   valid/acc: 0.1481
# Epoch: 7800   train/loss: 98.9612   valid/loss: 29.0166   train/acc: 0.2407   valid/acc: 0.1574
# Epoch: 8000   train/loss: 98.9797   valid/loss: 28.6792   train/acc: 0.2269   valid/acc: 0.1019
# Epoch: 8200   train/loss: 98.8683   valid/loss: 28.8294   train/acc: 0.2037   valid/acc: 0.1296
# Epoch: 8400   train/loss: 98.6617   valid/loss: 28.859   train/acc: 0.2546   valid/acc: 0.1574
# Epoch: 8600   train/loss: 98.5982   valid/loss: 28.563   train/acc: 0.1806   valid/acc: 0.1481
# Epoch: 8800   train/loss: 98.993   valid/loss: 28.587   train/acc: 0.2361   valid/acc: 0.1389
# Epoch: 9000   train/loss: 98.6302   valid/loss: 28.796   train/acc: 0.2199   valid/acc: 0.1204
# Epoch: 9200   train/loss: 98.4095   valid/loss: 28.9388   train/acc: 0.2338   valid/acc: 0.1111
# Epoch: 9400   train/loss: 98.4072   valid/loss: 29.0434   train/acc: 0.2569   valid/acc: 0.1481
# Epoch: 9600   train/loss: 98.4936   valid/loss: 28.8352   train/acc: 0.2361   valid/acc: 0.1296
# Epoch: 9800   train/loss: 98.3749   valid/loss: 28.6386   train/acc: 0.2454   valid/acc: 0.1019
# Epoch: 10000   train/loss: 98.4128   valid/loss: 28.5141   train/acc: 0.1852   valid/acc: 0.0926
# Test accuracy: 0.21100917431192662
# Progress:  0.982
# Number of training circuits: 433   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.984
# Number of training circuits: 434   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.987
# Number of training circuits: 435   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.989
# Number of training circuits: 436   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.991
# Number of training circuits: 437   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.993
# Number of training circuits: 438   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.996
# Number of training circuits: 439   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
# Progress:  0.998
# Number of training circuits: 440   Number of validation circuits: 108   Number of test circuits: 109   Number of parameters in model: 280
